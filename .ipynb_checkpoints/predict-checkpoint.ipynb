# %% [markdown]
# # March Madness 2024 | ML Bracket Prediction
# Author Glen Joy (c) 2024
#
# This notebook trains a random-forest model on historical NCAA college basketball statistics to make formulate a predicted bracket for the 2024 season.

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# ## 1. Reading in Training Data
# We will incorporate data from a variety of sources. This includes 'traditional' regular season team stats such as winning percentage, 3-pt percentage, free throw percentage, etc. We will also use a team's historic tournament performance.
#
# Since these are yearly stats, they will be merged on (Team Name, Year) where (Team Name, Year) is set as the multi-index.
#
# Additionally, for funzies, we'll incorporate external 'nontraditional' factors such as public rankings, school spirit, academic ranking, etc.

# %% [markdown]
# ### Data Source 1: Historic Team Stats

# %%
# Reading in historic team season stats data. Has data from 2013 to 2023
df = pd.read_csv('./data/archive1/cbb.csv')
df['WIN_PCT'] = df['W']/df['G']
df.drop(['G', 'W'], axis=1, inplace=True)
df.head()
# Out:
#              TEAM CONF  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  TORD   ORB  \
# 0  North Carolina  ACC  123.3   94.9   0.9531   52.6   48.1  15.4  18.2  40.7
# 1       Wisconsin  B10  129.1   93.6   0.9758   54.8   47.7  12.4  15.8  32.1
# 2        Michigan  B10  114.4   90.4   0.9375   53.9   47.7  14.0  19.5  25.5
# 3      Texas Tech  B12  115.2   85.2   0.9696   53.5   43.0  17.7  22.8  27.4
# 4         Gonzaga  WCC  117.8   86.3   0.9728   56.6   41.1  16.2  17.1  30.0
#
#    ...  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR   WIN_PCT
# 0  ...  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016  0.825000
# 1  ...  54.8  44.7  36.5  37.5   59.3  11.3         2ND   1.0  2015  0.900000
# 2  ...  54.7  46.8  35.2  33.2   65.9   6.9         2ND   3.0  2018  0.825000
# 3  ...  52.8  41.9  36.5  29.7   67.5   7.0         2ND   3.0  2019  0.815789
# 4  ...  56.3  40.0  38.2  29.0   71.5   7.7         2ND   1.0  2017  0.948718
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['TEAM', 'CONF', 'ADJOE', 'ADJDE', 'BARTHAG', 'EFG_O', 'EFG_D', 'TOR',
#        'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P_O', '2P_D', '3P_O', '3P_D',
#        'ADJ_T', 'WAB', 'POSTSEASON', 'SEED', 'YEAR', 'WIN_PCT'],
#       dtype='object')

# %% [markdown]
# ### Data Source 2: Historic Matchups

# %%
df2 = pd.read_csv('./data/MNCAATourneyCompactResults.csv')
df2['YEAR'] = df2['Season']
df2.drop(['Season'], axis=1, inplace=True)
df2.head()
# Out:
#    DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  YEAR
# 0     136     1116      63     1234      54    N      0  1985
# 1     136     1120      59     1345      58    N      0  1985
# 2     136     1207      68     1250      43    N      0  1985
# 3     136     1229      58     1425      55    N      0  1985
# 4     136     1242      49     1325      38    N      0  1985

# %% [markdown]
# ### Team Lookup Table

# %%
teamsdf = pd.read_csv('./data/MTeams.csv')
teamsdf.head()
# Out:
#    TeamID     TeamName  FirstD1Season  LastD1Season
# 0    1101  Abilene Chr           2014          2024
# 1    1102    Air Force           1985          2024
# 2    1103        Akron           1985          2024
# 3    1104      Alabama           1985          2024
# 4    1105  Alabama A&M           2000          2024

# %% [markdown]
# ### Data Source 3: Conference Stats

# %%
df3 = pd.read_csv('./data/archive/Conference Stats.csv') # this is regular season only!
df3 = df3[df3['YEAR'] != 2024] # removing imcomplete 2024 data
df3['WIN_PCT_CONF'] = df3['W']/df3['G']
df3.drop(['W', 'G', 'L', 'WIN%', 'CONF ID'], axis=1, inplace=True)
df3.head()
# Out:
#     YEAR CONF  BADJ EM  BADJ O  BADJ D  BARTHAG  EFG%  EFGD%   FTR  FTRD  ...  \
# 33  2023  B12     18.0   111.8    93.8    0.883  51.6   48.5  33.5  33.0  ...
# 34  2023  B10     14.2   110.4    96.2    0.830  51.1   48.7  29.5  26.6  ...
# 35  2023   BE     13.0   110.8    97.8    0.808  51.7   49.9  30.4  28.1  ...
# 36  2023  SEC     12.5   109.2    96.7    0.802  49.7   47.8  34.4  32.4  ...
# 37  2023  P12     11.4   107.9    96.5    0.783  49.9   47.9  31.1  28.8  ...
#
#     EFF HGT    EXP  TALENT   FT%  OP FT%   PPPO   PPPD  ELITE SOS  WAB  \
# 33   80.522  2.140  55.266  72.5    71.7  1.059  0.978     34.920  2.9
# 34   80.919  1.845  55.026  71.1    70.7  1.061  1.001     31.036  0.2
# 35   80.679  1.935  54.668  73.5    72.7  1.065  1.019     30.790 -1.0
# 36   80.909  1.968  47.670  71.1    71.5  1.053  0.998     28.681 -0.8
# 37   81.439  1.855  55.558  71.7    71.0  1.030  0.991     28.629 -2.2
#
#     WIN_PCT_CONF
# 33      0.629969
# 34      0.585526
# 35      0.561111
# 36      0.591304
# 37      0.544529
#
# [5 rows x 41 columns]

# %%
df3.columns
# Out:
# Index(['YEAR', 'CONF', 'BADJ EM', 'BADJ O', 'BADJ D', 'BARTHAG', 'EFG%',
#        'EFGD%', 'FTR', 'FTRD', 'TOV%', 'TOV%D', 'OREB%', 'DREB%', 'OP OREB%',
#        'OP DREB%', 'RAW T', '2PT%', '2PT%D', '3PT%', '3PT%D', 'BLK%', 'BLKED%',
#        'AST%', 'OP AST %', '2PTR', '3PTR', '2PTRD', '3PTRD', 'BADJ T',
#        'AVG HGT', 'EFF HGT', 'EXP', 'TALENT', 'FT%', 'OP FT%', 'PPPO', 'PPPD',
#        'ELITE SOS', 'WAB', 'WIN_PCT_CONF'],
#       dtype='object')

# %% [markdown]
# ## 2. Merging, Fusing, and Deconflicting Datasets
# We will combine all of these datasets into a large one to train using.

# %% [markdown]
# #### Combining Team and Conference Stats by Year

# %%
cdf = pd.merge(df, df3, on=['CONF', 'YEAR'], how='outer') # merging team stats and conference stats

# %%
cdf.head()
# Out:
#   TEAM CONF  ADJOE  ADJDE  BARTHAG_x  EFG_O  EFG_D  TOR  TORD  ORB  ...  \
# 0  NaN  A10    NaN    NaN        NaN    NaN    NaN  NaN   NaN  NaN  ...
# 1  NaN  A10    NaN    NaN        NaN    NaN    NaN  NaN   NaN  NaN  ...
# 2  NaN  A10    NaN    NaN        NaN    NaN    NaN  NaN   NaN  NaN  ...
# 3  NaN  A10    NaN    NaN        NaN    NaN    NaN  NaN   NaN  NaN  ...
# 4  NaN  A10    NaN    NaN        NaN    NaN    NaN  NaN   NaN  NaN  ...
#
#    EFF HGT    EXP  TALENT   FT%  OP FT%   PPPO   PPPD  ELITE SOS  WAB_y  \
# 0   80.066  1.819  24.809  70.3    70.0  1.050  1.015     21.975   -4.2
# 1   80.241  1.673  28.691  68.2    68.7  1.026  1.004     19.678   -6.0
# 2   80.307  1.558  29.958  67.7    67.6  1.017  0.995     23.936   -4.5
# 3   80.413  1.609  30.035  68.4    69.8  1.020  1.003     18.832   -6.2
# 4   79.954  1.660  28.115  70.2    71.0  1.034  1.004     22.225   -3.5
#
#   WIN_PCT_CONF
# 0     0.561485
# 1     0.540230
# 2     0.554023
# 3     0.537757
# 4     0.552511
#
# [5 rows x 62 columns]

# %%
cdf.columns
# Out:
# Index(['TEAM', 'CONF', 'ADJOE', 'ADJDE', 'BARTHAG_x', 'EFG_O', 'EFG_D', 'TOR',
#        'TORD', 'ORB', 'DRB', 'FTR_x', 'FTRD_x', '2P_O', '2P_D', '3P_O', '3P_D',
#        'ADJ_T', 'WAB_x', 'POSTSEASON', 'SEED', 'YEAR', 'WIN_PCT', 'BADJ EM',
#        'BADJ O', 'BADJ D', 'BARTHAG_y', 'EFG%', 'EFGD%', 'FTR_y', 'FTRD_y',
#        'TOV%', 'TOV%D', 'OREB%', 'DREB%', 'OP OREB%', 'OP DREB%', 'RAW T',
#        '2PT%', '2PT%D', '3PT%', '3PT%D', 'BLK%', 'BLKED%', 'AST%', 'OP AST %',
#        '2PTR', '3PTR', '2PTRD', '3PTRD', 'BADJ T', 'AVG HGT', 'EFF HGT', 'EXP',
#        'TALENT', 'FT%', 'OP FT%', 'PPPO', 'PPPD', 'ELITE SOS', 'WAB_y',
#        'WIN_PCT_CONF'],
#       dtype='object')

# %%
cdf = cdf[cdf['TEAM'].notna()] # dropping rows where we have conference data but no corresponding team
cdf.head()
# Out:
#                 TEAM CONF  ADJOE  ADJDE  BARTHAG_x  EFG_O  EFG_D   TOR  TORD  \
# 5  George Washington  A10   98.8   93.0     0.6650   46.6   47.4  23.4  21.3
# 6    St. Bonaventure  A10  107.9  102.5     0.6442   51.6   51.6  20.0  21.5
# 7             Dayton  A10  111.8   99.4     0.7951   53.0   49.2  21.7  21.0
# 8             Xavier  A10  105.1   94.3     0.7765   50.1   46.7  20.4  18.6
# 9     Saint Joseph's  A10  107.4   96.8     0.7681   50.6   46.1  18.7  16.2
#
#     ORB  ...  EFF HGT    EXP  TALENT   FT%  OP FT%   PPPO  PPPD  ELITE SOS  \
# 5  38.2  ...   79.886  1.705  29.413  69.6    69.9  1.033   1.0     23.936
# 6  32.3  ...   79.886  1.705  29.413  69.6    69.9  1.033   1.0     23.936
# 7  35.2  ...   79.886  1.705  29.413  69.6    69.9  1.033   1.0     23.936
# 8  34.3  ...   79.886  1.705  29.413  69.6    69.9  1.033   1.0     23.936
# 9  31.7  ...   79.886  1.705  29.413  69.6    69.9  1.033   1.0     23.936
#
#    WAB_y WIN_PCT_CONF
# 5   -3.4     0.567134
# 6   -3.4     0.567134
# 7   -3.4     0.567134
# 8   -3.4     0.567134
# 9   -3.4     0.567134
#
# [5 rows x 62 columns]

# %%
cdf.size
# Out:
# 218426

# %% [markdown]
# #### Embelishing Team/Conference Stats with Historic Matchups

# %%
df2 = df2[df2['YEAR'] >= 2008] # looking at 2008 and up since thats when all our data overlaps

# %%
df2.head()
# Out:
#       DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  YEAR
# 1456     134     1291      69     1164      60    N      0  2008
# 1457     136     1181      71     1125      70    N      0  2008
# 1458     136     1242      85     1340      61    N      0  2008
# 1459     136     1243      80     1425      67    N      0  2008
# 1460     136     1266      74     1246      66    N      0  2008

# %%
teamsdf.set_index('TeamID', inplace=True)

# %%
teamsdf.head()
# Out:
#            TeamName  FirstD1Season  LastD1Season
# TeamID
# 1101    Abilene Chr           2014          2024
# 1102      Air Force           1985          2024
# 1103          Akron           1985          2024
# 1104        Alabama           1985          2024
# 1105    Alabama A&M           2000          2024

# %%
df2.head()
# Out:
#       DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  YEAR
# 1456     134     1291      69     1164      60    N      0  2008
# 1457     136     1181      71     1125      70    N      0  2008
# 1458     136     1242      85     1340      61    N      0  2008
# 1459     136     1243      80     1425      67    N      0  2008
# 1460     136     1266      74     1246      66    N      0  2008

# %%
# Looking up and replacing team ID with string name
df2['WTEAM'] = df2.apply(lambda row : teamsdf.loc[row['WTeamID']]['TeamName'], axis=1)

df2['LTEAM'] = df2.apply(lambda row : teamsdf.loc[row['LTeamID']]['TeamName'], axis=1)

df2['TEAM_1'] = df2.apply(lambda row : random.choice([row['WTEAM'], row['LTEAM']]), axis=1)
df2['TEAM_2'] = df2.apply(lambda row : row['LTEAM'] if row['TEAM_1'] == row['WTEAM'] else row['WTEAM'], axis=1)

df2['WINNER'] = df2.apply(lambda row : 1 if row['TEAM_1'] == row['WTEAM'] else 2, axis=1)

# %%
df2.columns
# Out:
# Index(['DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc', 'NumOT',
#        'YEAR', 'WTEAM', 'LTEAM', 'TEAM_1', 'TEAM_2', 'WINNER'],
#       dtype='object')

# %%
df2.drop(['DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc', 'NumOT', 'WTEAM', 'LTEAM'], axis=1, inplace=True)

# %%
cdf.YEAR.min()
# Out:
# 2013

# %%
df2 = df2[df2['YEAR'] >= 2013]

# %%
cdf['TEAM'] = cdf['TEAM'].apply(lambda name : name.strip('.'))

# %%
df2.shape
# Out:
# (669, 4)

# %%
tdfs = []
for year in df2['YEAR'].unique():
    df_temp = df2[df2['YEAR'] == year].copy()
    cdf_temp = cdf[cdf['YEAR'] == year].copy()
    df_temp = df_temp.merge(cdf_temp, left_on='TEAM_1', right_on='TEAM', suffixes=['_ONE', '_TWO'])
    df_temp = df_temp.merge(cdf_temp, left_on='TEAM_2', right_on='TEAM', suffixes=['_ONE', '_TWO'])
    tdfs.append(df_temp.copy())
traindf = pd.concat(tdfs)

# %%
traindf.head()
# Out:
#    YEAR_ONE         TEAM_1        TEAM_2  WINNER       TEAM_ONE CONF_ONE  \
# 0      2013  James Madison  LIU Brooklyn       1  James Madison      CAA
# 1      2013       La Salle      Boise St       1       La Salle      A10
# 2      2013        Arizona       Belmont       1        Arizona      P12
# 3      2013       Bucknell        Butler       2       Bucknell      Pat
# 4      2013     California          UNLV       1     California      P12
#
#    ADJOE_ONE  ADJDE_ONE  BARTHAG_x_ONE  EFG_O_ONE  ...  EFF HGT_TWO  EXP_TWO  \
# 0       98.5       99.4         0.4736       47.6  ...       78.546    1.787
# 1      112.0       96.2         0.8516       51.9  ...       80.035    1.826
# 2      114.4       92.2         0.9229       52.5  ...       78.906    1.956
# 3      104.7       93.1         0.7936       49.6  ...       79.886    1.705
# 4      105.4       92.3         0.8211       48.0  ...       80.035    1.826
#
#    TALENT_TWO  FT%_TWO  OP FT%_TWO  PPPO_TWO  PPPD_TWO  ELITE SOS_TWO  \
# 0       5.367     70.1        69.5     1.019     1.055         11.752
# 1      24.940     70.8        68.8     1.031     0.980         25.212
# 2       4.688     70.7        71.2     1.018     1.038         12.869
# 3      29.413     69.6        69.9     1.033     1.000         23.936
# 4      24.940     70.8        68.8     1.031     0.980         25.212
#
#    WAB_y_TWO  WIN_PCT_CONF_TWO
# 0      -11.5          0.459459
# 1       -1.4          0.611722
# 2      -10.0          0.474138
# 3       -3.4          0.567134
# 4       -1.4          0.611722
#
# [5 rows x 128 columns]

# %%
new_name = 'YEAR'
traindf = traindf.rename(columns={'YEAR_ONE': new_name})
traindf.drop(['SEED_ONE', 'YEAR_TWO', 'SEED_TWO'], axis=1, inplace=True)

# %%
traindf.shape
# Out:
# (538, 125)

# %% [markdown]
# ## 2. Training Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %%
labels = np.array(traindf['WINNER'])

# %%
traindf = traindf.drop(['WINNER', 'TEAM_1', 'TEAM_2', 'TEAM_ONE', 'TEAM_TWO', 'CONF_ONE', 'CONF_TWO', 'POSTSEASON_ONE', 'POSTSEASON_TWO'], axis=1)

# %%
# splitting our data into training data and test data, specifically using 25% for testing
train_features, test_features, train_labels, test_labels = train_test_split(traindf, labels, test_size = 0.20, random_state = 42)

# %%
# Instantiate model with 5000 decision trees
rf = RandomForestClassifier(n_estimators = 5000, random_state = 42)
# Train the model on training data
rf.fit(train_features.values, train_labels);

# %%
predictions = rf.predict(test_features)
# Out:
# /Users/glenjoy/anaconda3/envs/bp/lib/python3.12/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(

# %%
# Checking Accuracy
print("Accuracy:",metrics.accuracy_score(test_labels, predictions))
# Out:
# Accuracy: 0.7407407407407407

# %%
traindf.head()
# Out:
#    YEAR  ADJOE_ONE  ADJDE_ONE  BARTHAG_x_ONE  EFG_O_ONE  EFG_D_ONE  TOR_ONE  \
# 0  2013       98.5       99.4         0.4736       47.6       48.7     17.2
# 1  2013      112.0       96.2         0.8516       51.9       49.3     17.1
# 2  2013      114.4       92.2         0.9229       52.5       46.6     19.5
# 3  2013      104.7       93.1         0.7936       49.6       42.5     15.1
# 4  2013      105.4       92.3         0.8211       48.0       44.3     18.9
#
#    TORD_ONE  ORB_ONE  DRB_ONE  ...  EFF HGT_TWO  EXP_TWO  TALENT_TWO  FT%_TWO  \
# 0      21.1     29.6     31.1  ...       78.546    1.787       5.367     70.1
# 1      21.3     29.0     34.2  ...       80.035    1.826      24.940     70.8
# 2      19.8     35.0     26.7  ...       78.906    1.956       4.688     70.7
# 3      14.1     29.3     24.3  ...       79.886    1.705      29.413     69.6
# 4      16.8     32.5     30.7  ...       80.035    1.826      24.940     70.8
#
#    OP FT%_TWO  PPPO_TWO  PPPD_TWO  ELITE SOS_TWO  WAB_y_TWO  WIN_PCT_CONF_TWO
# 0        69.5     1.019     1.055         11.752      -11.5          0.459459
# 1        68.8     1.031     0.980         25.212       -1.4          0.611722
# 2        71.2     1.018     1.038         12.869      -10.0          0.474138
# 3        69.9     1.033     1.000         23.936       -3.4          0.567134
# 4        68.8     1.031     0.980         25.212       -1.4          0.611722
#
# [5 rows x 116 columns]

# %% [markdown]
# ## 3. Importing 2024 Data

# %%
# reading in 2024 seasonal data
df24 = pd.read_csv('./data/2024_formatted.csv')
df24.drop('Unnamed: 0', axis=1, inplace=True)
df24.head()
# Out:
#           TEAM CONF  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  TORD   ORB  \
# 0      Houston  B12  119.1   85.7   0.9778   49.7   44.0  13.7  24.7  36.9
# 1  Connecticut   BE  126.9   93.8   0.9700   57.1   45.1  14.9  16.2  36.5
# 2       Purdue  B10  126.2   94.8   0.9640   56.0   47.7  16.5  14.0  37.4
# 3     Iowa St.  B12  113.5   86.7   0.9569   51.9   47.1  15.7  25.7  31.6
# 4       Auburn  SEC  120.7   92.2   0.9569   54.1   43.4  14.9  18.2  32.9
#
#    ...  2P_O  2P_D  3P_O  3P_D   3PR  3PRD  ADJ_T   WAB   WIN_PCT  YEAR
# 0  ...  48.4  43.4  34.7  30.0  36.6  40.9   63.4  10.4  0.882353  2024
# 1  ...  58.5  43.7  36.7  31.9  40.9  33.2   64.6  11.0  0.911765  2024
# 2  ...  53.2  48.1  40.8  31.4  35.0  37.2   67.6  10.9  0.878788  2024
# 3  ...  51.7  46.9  34.9  31.5  32.0  45.0   67.6   6.7  0.794118  2024
# 4  ...  54.9  42.8  35.2  29.8  37.5  33.3   69.9   5.4  0.794118  2024
#
# [5 rows x 23 columns]

# %%
# reading in 2024 conference stats
cf24 = pd.read_csv('./data/archive/Conference Stats.csv') # this is regular season only!
cf24 = cf24[cf24['YEAR'] == 2024]
cf24.head()
# Out:
#    YEAR  CONF ID CONF  BADJ EM  BADJ O  BADJ D  BARTHAG    G    W    L  ...  \
# 0  2024        7  B12     16.8   113.2    96.4    0.864  375  243  132  ...
# 1  2024        6  B10     15.1   113.6    98.5    0.838  386  233  153  ...
# 2  2024       28  SEC     14.2   113.8    99.6    0.822  378  232  146  ...
# 3  2024        8   BE     13.6   112.6    99.0    0.815  300  173  127  ...
# 4  2024        2  ACC     11.5   110.9    99.4    0.779  410  241  169  ...
#
#    AVG HGT  EFF HGT    EXP  TALENT   FT%  OP FT%   PPPO   PPPD  ELITE SOS  WAB
# 0   77.615   80.941  2.092  48.691  72.0    71.2  1.099  0.986     29.010  1.0
# 1   77.906   81.153  1.987  57.308  72.4    72.3  1.099  1.028     29.652  0.1
# 2   77.608   81.094  2.083  48.953  73.0    72.6  1.107  1.036     28.276 -0.1
# 3   77.727   80.761  2.107  50.457  74.5    73.2  1.089  1.032     30.625 -0.4
# 4   77.902   81.051  1.648  61.688  73.6    72.8  1.081  1.026     26.024 -1.3
#
# [5 rows x 45 columns]

# %%
cf24['WIN_PCT_CONF'] = cf24['W']/cf24['G']
cf24.drop(['W', 'G', 'L', 'WIN%', 'CONF ID'], axis=1, inplace=True)
cf24.head()
# Out:
#    YEAR CONF  BADJ EM  BADJ O  BADJ D  BARTHAG  EFG%  EFGD%   FTR  FTRD  ...  \
# 0  2024  B12     16.8   113.2    96.4    0.864  52.2   48.2  33.6  31.4  ...
# 1  2024  B10     15.1   113.6    98.5    0.838  51.7   48.9  35.1  31.1  ...
# 2  2024  SEC     14.2   113.8    99.6    0.822  51.3   48.6  35.9  33.8  ...
# 3  2024   BE     13.6   112.6    99.0    0.815  51.7   49.2  30.2  27.9  ...
# 4  2024  ACC     11.5   110.9    99.4    0.779  51.4   49.5  31.9  30.0  ...
#
#    EFF HGT    EXP  TALENT   FT%  OP FT%   PPPO   PPPD  ELITE SOS  WAB  \
# 0   80.941  2.092  48.691  72.0    71.2  1.099  0.986     29.010  1.0
# 1   81.153  1.987  57.308  72.4    72.3  1.099  1.028     29.652  0.1
# 2   81.094  2.083  48.953  73.0    72.6  1.107  1.036     28.276 -0.1
# 3   80.761  2.107  50.457  74.5    73.2  1.089  1.032     30.625 -0.4
# 4   81.051  1.648  61.688  73.6    72.8  1.081  1.026     26.024 -1.3
#
#    WIN_PCT_CONF
# 0      0.648000
# 1      0.603627
# 2      0.613757
# 3      0.576667
# 4      0.587805
#
# [5 rows x 41 columns]

# %%
pdf = pd.merge(df24, cf24, on=['CONF', 'YEAR'], how='outer') # merging team stats and conference stats
pdf.head()
# Out:
#              TEAM CONF  ADJOE  ADJDE  BARTHAG_x  EFG_O  EFG_D   TOR  TORD  \
# 0          Dayton  A10  117.5  100.8     0.8535   56.6   47.9  15.8  15.7
# 1        Duquesne  A10  106.4   96.2     0.7619   50.1   48.0  17.5  19.5
# 2  North Carolina  ACC  116.8   93.4     0.9291   51.3   46.4  14.4  14.9
# 3            Duke  ACC  120.8   97.0     0.9259   55.2   49.0  14.3  16.9
# 4         Clemson  ACC  116.7   99.4     0.8630   53.9   48.7  14.9  13.6
#
#     ORB  ...  EFF HGT    EXP  TALENT   FT%  OP FT%   PPPO   PPPD  ELITE SOS  \
# 0  26.9  ...   80.244  1.872  18.179  72.2    71.7  1.073  1.033     17.561
# 1  29.9  ...   80.244  1.872  18.179  72.2    71.7  1.073  1.033     17.561
# 2  32.8  ...   81.051  1.648  61.688  73.6    72.8  1.081  1.026     26.024
# 3  31.8  ...   81.051  1.648  61.688  73.6    72.8  1.081  1.026     26.024
# 4  27.7  ...   81.051  1.648  61.688  73.6    72.8  1.081  1.026     26.024
#
#    WAB_y  WIN_PCT_CONF
# 0   -4.2      0.579345
# 1   -4.2      0.579345
# 2   -1.3      0.587805
# 3   -1.3      0.587805
# 4   -1.3      0.587805
#
# [5 rows x 62 columns]

# %%
pdf = pdf[pdf['TEAM'].notna()]

# %% [markdown]
# ## 4. Running Predictor for 2024

# %%
pdf['TEAM'].unique()
# Out:
# array(['Dayton', 'Duquesne', 'North Carolina', 'Duke', 'Clemson',
#        'North Carolina St.', 'Virginia', 'Vermont', 'Stetson',
#        'Florida Atlantic', 'UAB', 'Purdue', 'Illinois', 'Wisconsin',
#        'Nebraska', 'Michigan St.', 'Northwestern', 'Houston', 'Iowa St.',
#        'Kansas', 'Baylor', 'BYU', 'Texas', 'Texas Tech', 'TCU',
#        'Connecticut', 'Marquette', 'Creighton', 'Montana St.', 'Longwood',
#        'Long Beach St.', 'College of Charleston', 'Western Kentucky',
#        'Oakland', 'Yale', "Saint Peter's", 'Akron', 'Howard', 'Drake',
#        'New Mexico', 'San Diego St.', 'Nevada', 'Colorado St.',
#        'Boise St.', 'Utah St.', 'Wagner', 'Morehead St.', 'Arizona',
#        'Colorado', 'Washington St.', 'Oregon', 'Colgate', 'James Madison',
#        'Samford', 'Auburn', 'Tennessee', 'Alabama', 'Florida', 'Kentucky',
#        'Mississippi St.', 'Texas A&M', 'South Carolina', 'Grambling St.',
#        'McNeese St.', 'South Dakota St.', 'Grand Canyon', "Saint Mary's",
#        'Gonzaga'], dtype=object)

# %%
len(pdf['TEAM'].unique()) # 68 teams as expected
# Out:
# 68

# %%
def construct_matchup(team1, team2):
    pdf_temp = pdf.copy()
    team1_data = pdf_temp[pdf_temp['TEAM'] == team1]
    team2_data = pdf_temp[pdf_temp['TEAM'] == team2]
    input_data = team1_data.merge(team2_data, on='YEAR', suffixes=['_ONE', '_TWO']).copy()
    input_data.drop(['TEAM_ONE',
 'CONF_ONE',
 '3PR_ONE',
 '3PRD_ONE',
 'TEAM_TWO',
 'CONF_TWO',
 '3PR_TWO',
 '3PRD_TWO'], axis=1, inplace=True)
    return input_data

# %%
test = construct_matchup('Clemson', 'Duke') # example

# %%
test.head()
# Out:
#    ADJOE_ONE  ADJDE_ONE  BARTHAG_x_ONE  EFG_O_ONE  EFG_D_ONE  TOR_ONE  \
# 0      116.7       99.4          0.863       53.9       48.7     14.9
#
#    TORD_ONE  ORB_ONE  DRB_ONE  FTR_x_ONE  ...  EFF HGT_TWO  EXP_TWO  \
# 0      13.6     27.7     25.2       30.6  ...       81.051    1.648
#
#    TALENT_TWO  FT%_TWO  OP FT%_TWO  PPPO_TWO  PPPD_TWO  ELITE SOS_TWO  \
# 0      61.688     73.6        72.8     1.081     1.026         26.024
#
#    WAB_y_TWO  WIN_PCT_CONF_TWO
# 0       -1.3          0.587805
#
# [1 rows x 115 columns]

# %% [markdown]
# ### Code from simulator.ipynb to automatically predict full bracket

# %%
def predict(team1, team2):
    input_data = construct_matchup(team1, team2)
    input_data = input_data[traindf.columns] # to ensure column ordering matches that of training data
    try:  
        result = rf.predict(np.array(input_data).reshape(1,-1))
    except ValueError:
        print(f'Either {team1} or {team2} not in list')
    if result == 1:
        winner = team1
    else:
        winner = team2
    print(f"Between {team1} and {team2} | {winner} won!")
    return winner

# %%
predict('Connecticut', 'Stetson') # test prediction
# Out:
# Between Connecticut and Stetson | Connecticut won!
# 'Connecticut'

# %%
def create_matchups(seeds):
  """
  Creates a dictionary mapping games to team matchups based on seed order.

  Args:
      seeds: Dictionary mapping team names to their seed.

  Returns:
      A dictionary mapping game numbers to team matchups.
  """
  sorted_seeds = dict(sorted(seeds.items(), key=lambda item: item[1]))
  teams = list(sorted_seeds.keys())
  num_games = len(teams) // 2
  matchups = {}
  for i in range(num_games):
    matchups[i+1] = (teams[i], teams[-i-1])  # Use integer index for game number
  return matchups

# %%
def simulate_regionals(region):
    print('------------')
    matches = create_matchups(region)
    winners = {}
    for i, teams in matches.items():
        winner = predict(teams[0], teams[1])
        winners[winner] = i
        
    matches2 = create_matchups(winners)
    winners2 = {}
    for i, teams in matches2.items():
        winner = predict(teams[0], teams[1])
        winners2[winner] = i

    matches3 = create_matchups(winners2)
    winners3 = {}
    for i, teams in matches3.items():
        winner = predict(teams[0], teams[1])
        winners3[winner] = i

    matches4 = create_matchups(winners3)
    regional_winner = None
    for i, teams in matches4.items():
        regional_winner = predict(teams[0], teams[1])
    return regional_winner

# %%
# ... (other functions remain the same)

def simulate_tournament(regions):

    final_four = []
    
    for region in regions:
        final_four.append(simulate_regionals(region))


    print('-----SEMI FINALS-------')
    # semifinals
    w1 = predict(final_four[0], final_four[1])
    w2 = predict(final_four[2], final_four[3])

    #final
    print('-----FINALS-------')
    predict(w1, w2)

# %%
# User input for team names and seeds
def read_teams_from_file(filename):
  regions = []
  current_region = []
  with open(filename, "r") as file:
    for line in file:
      line = line.strip()  # Remove leading/trailing whitespace
      if line:  # Skip empty lines
        current_region.append(line)
      elif current_region:  # If a region is complete, process it
        regions.append({team: i+1 for i, team in enumerate(current_region)})
        current_region = []
  if current_region:  # Process the last region
    regions.append({team: i+1 for i, team in enumerate(current_region)})
  return regions

# Get filename from user and read regions
filename = '24list.txt'
regions = read_teams_from_file(filename)

simulate_tournament(regions)
# print(bracket_results)
# Out:
# ------------
# Between North Carolina and Wagner | North Carolina won!
# Between Arizona and Long Beach St. | Arizona won!
# Between Baylor and Colgate | Baylor won!
# Between Alabama and College of Charleston | Alabama won!
# Between Saint Mary's and Grand Canyon | Saint Mary's won!
# Between Clemson and New Mexico | New Mexico won!
# Between Dayton and Nevada | Nevada won!
# Between Mississippi St. and Michigan St. | Michigan St. won!
# Between North Carolina and Michigan St. | North Carolina won!
# Between Arizona and Nevada | Arizona won!
# Between Baylor and New Mexico | Baylor won!
# Between Alabama and Saint Mary's | Saint Mary's won!
# Between North Carolina and Saint Mary's | North Carolina won!
# Between Arizona and Baylor | Arizona won!
# Between North Carolina and Arizona | North Carolina won!
# ------------
# Between Connecticut and Stetson | Connecticut won!
# Between Iowa St. and South Dakota St. | Iowa St. won!
# Between Illinois and Morehead St. | Illinois won!
# Between Auburn and Yale | Auburn won!
# Between San Diego St. and UAB | San Diego St. won!
# Between BYU and Duquesne | BYU won!
# Between Washington St. and Drake | Drake won!
# Between Florida Atlantic and Northwestern | Northwestern won!
# Between Connecticut and Northwestern | Connecticut won!
# Between Iowa St. and Drake | Iowa St. won!
# Between Illinois and BYU | Illinois won!
# Between Auburn and San Diego St. | Auburn won!
# Between Connecticut and Auburn | Connecticut won!
# Between Iowa St. and Illinois | Iowa St. won!
# Between Connecticut and Iowa St. | Connecticut won!
# ------------
# Between Houston and Longwood | Houston won!
# Between Marquette and Western Kentucky | Marquette won!
# Between Kentucky and Oakland | Kentucky won!
# Between Duke and Vermont | Duke won!
# Between Wisconsin and James Madison | Wisconsin won!
# Between Texas Tech and North Carolina St. | Texas Tech won!
# Between Florida and Colorado | Colorado won!
# Between Nebraska and Texas A&M | Nebraska won!
# Between Houston and Nebraska | Houston won!
# Between Marquette and Colorado | Marquette won!
# Between Kentucky and Texas Tech | Kentucky won!
# Between Duke and Wisconsin | Duke won!
# Between Houston and Duke | Houston won!
# Between Marquette and Kentucky | Marquette won!
# Between Houston and Marquette | Houston won!
# ------------
# Between Purdue and Grambling St. | Purdue won!
# Between Tennessee and Saint Peter's | Tennessee won!
# Between Creighton and Akron | Creighton won!
# Between Kansas and Samford | Kansas won!
# Between Gonzaga and McNeese St. | Gonzaga won!
# Between South Carolina and Oregon | Oregon won!
# Between Texas and Colorado St. | Texas won!
# Between Utah St. and TCU | TCU won!
# Between Purdue and TCU | Purdue won!
# Between Tennessee and Texas | Tennessee won!
# Between Creighton and Oregon | Creighton won!
# Between Kansas and Gonzaga | Kansas won!
# Between Purdue and Kansas | Purdue won!
# Between Tennessee and Creighton | Tennessee won!
# Between Purdue and Tennessee | Purdue won!
# -----SEMI FINALS-------
# Between North Carolina and Connecticut | Connecticut won!
# Between Houston and Purdue | Purdue won!
# -----FINALS-------
# Between Connecticut and Purdue | Purdue won!
